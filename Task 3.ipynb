# %%
# !pip install jieba
# Out:
# ...
#   Using cached jieba-0.42.1.tar.gz (19.2 MB)
# ...
#   Created wheel for jieba: filename=jieba-0.42.1-py3-none-any.whl size=19314481 sha256=b7ce99385f9acfa2a0807759d6cfa9d27ea767c00d8b7aa7f5d89eef4b5f11de
#   Stored in directory: c:\users\nayni\appdata\local\pip\cache\wheels\24\aa\17\5bc7c72e9a37990a9620cc3aad0acad1564dcff6dbc2359de3
# Successfully built jieba
# ...

# %%
import jieba
seg = jieba.cut("網站有中、英文版本，也有繁、簡體版，可通過每頁左上角的連結隨時調整。", cut_all = True)
print(" ".join(seg))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\nayni\AppData\Local\Temp\jieba.cache
# Loading model cost 0.872 seconds.
# Prefix dict has been built successfully.
# 網 站 有 中 、 英文 英文版 文版 版本 ， 也 有 繁 、 簡 體 版 ， 可 通 過 每 頁 左上 左上角 上角 的 連 結 隨 時 調 整 。

# %%
seg1 = jieba.cut("把句子中所有的可以成词的词语都扫描出来", cut_all = True)
print(" ".join(seg1))
# Out:
# 把 句子 中所 所有 的 可以 成 词 的 词语 都 扫描 描出 描出来 出来

# %% [markdown]
# # Task 1: Basic text processing pipeline

# %%
import nltk
texts = """You don't know what's beautiful.
When you're staring at a cubical.
Big bangs in this thought train say you can't escape the universe.
The irony is like hide and seek, all you have to do is observe.
I am this planet from the dust and the earth.
The rogue companion in vantage, ink slanted.
Riding through valleys of death and Greek canyons.
I keep trying to talk English, but I think Sanskrit.
I don't need no stunt double or stand ins."""

for text in texts:
    sentences = nltk.sent_tokenize(texts)
    #print(sentences)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        print(words)
        tagged = nltk.pos_tag(words)
        #print(tagged)
# Out:
# ['You', 'do', "n't", 'know', 'what', "'s", 'beautiful', '.']
# ['When', 'you', "'re", 'staring', 'at', 'a', 'cubical', '.']
# ['Big', 'bangs', 'in', 'this', 'thought', 'train', 'say', 'you', 'ca', "n't", 'escape', 'the', 'universe', '.']
# ['The', 'irony', 'is', 'like', 'hide', 'and', 'seek', ',', 'all', 'you', 'have', 'to', 'do', 'is', 'observe', '.']
# ['I', 'am', 'this', 'planet', 'from', 'the', 'dust', 'and', 'the', 'earth', '.']
# ['The', 'rogue', 'companion', 'in', 'vantage', ',', 'ink', 'slanted', '.']
# ['Riding', 'through', 'valleys', 'of', 'death', 'and', 'Greek', 'canyons', '.']
# ['I', 'keep', 'trying', 'to', 'talk', 'English', ',', 'but', 'I', 'think', 'Sanskrit', '.']
# ['I', 'do', "n't", 'need', 'no', 'stunt', 'double', 'or', 'stand', 'ins', '.']
# ['You', 'do', "n't", 'know', 'what', "'s", 'beautiful', '.']
# ['When', 'you', "'re", 'staring', 'at', 'a', 'cubical', '.']
# ...

# %% [markdown]
# # Task 2: Tweet Tokenizer

# %%
import nltk
from nltk.tokenize import TweetTokenizer
text = 'The party was soooooo much fun :D #superfun'
twtkn = TweetTokenizer()
twtkn.tokenize(text)
# Out:
# ['The', 'party', 'was', 'soooooo', 'much', 'fun', ':D', '#superfun']

# %%
from nltk.tokenize import MWETokenizer
mtkn = MWETokenizer()
mtkn.tokenize(text)
# Out:
# ['T',
#  'h',
#  'e',
#  ' ',
#  'p',
#  'a',
#  'r',
#  't',
#  'y',
#  ' ',
#  'w',
#  'a',
#  's',
#  ' ',
#  's',
#  'o',
#  'o',
#  'o',
#  'o',
#  'o',
#  'o',
#  ' ',
#  'm',
#  'u',
#  'c',
#  'h',
#  ' ',
#  'f',
#  'u',
#  'n',
#  ' ',
#  ':',
#  'D',
#  ' ',
#  '#',
#  's',
#  'u',
#  'p',
#  'e',
#  'r',
#  'f',
#  'u',
#  'n']

# %% [markdown]
# # Task 3: Scraping data from web

# %%
from urllib import request
url = "https://www.gutenberg.org/files/2554/2554-0.txt"
response = request.urlopen(url)
raw = response.read().decode('utf8')
type(raw)
#print(raw[:50])
from nltk.tokenize import word_tokenize
tokens = word_tokenize(raw)
type(tokens)
#print(tokens)

text = nltk.Text(tokens)
#print(text[1024:1102])
words = [w.lower() for w in text]
vocab = sorted(set(words))
print(v)

#HTML > ASCII > TOKEN > TEXT > VOCAB
